# %%
# %sql
-- Create the catalog
CREATE CATALOG IF NOT EXISTS retail_store;

-- Create the three Medallion Architecture schemas
CREATE SCHEMA IF NOT EXISTS retail_store.bronze;
CREATE SCHEMA IF NOT EXISTS retail_store.silver;
CREATE SCHEMA IF NOT EXISTS retail_store.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create a Volume in the bronze schema
CREATE VOLUME IF NOT EXISTS retail_store.bronze.raw_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# check uploaded files
display(dbutils.fs.ls("/Volumes/retail_store/bronze/raw_data/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/retail_store/bronze/raw_data/customer_profiles.csv</td><td>customer_profiles.csv</td><td>28362</td><td>1773600097000</td></tr><tr><td>dbfs:/Volumes/retail_store/bronze/raw_data/product_inventory.csv</td><td>product_inventory.csv</td><td>7808</td><td>1773600097000</td></tr><tr><td>dbfs:/Volumes/retail_store/bronze/raw_data/sales_transaction.csv</td><td>sales_transaction.csv</td><td>150162</td><td>1773600097000</td></tr></tbody></table></div>

# %%
#examine uploaded customer_profile file
spark.read.csv(
    "/Volumes/retail_store/bronze/raw_data/customer_profiles.csv",
    header=True
).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>Age</th><th>Gender</th><th>Location</th><th>JoinDate</th></tr></thead><tbody><tr><td>1</td><td>63</td><td>Other</td><td>East</td><td>01/01/20</td></tr><tr><td>2</td><td>63</td><td>Male</td><td>North</td><td>02/01/20</td></tr><tr><td>3</td><td>34</td><td>Other</td><td>North</td><td>03/01/20</td></tr><tr><td>4</td><td>19</td><td>Other</td><td>null</td><td>04/01/20</td></tr><tr><td>5</td><td>57</td><td>Male</td><td>North</td><td>05/01/20</td></tr></tbody></table></div>

# %%
#examine product_inventory file
spark.read.csv(
    "/Volumes/retail_store/bronze/raw_data/product_inventory.csv",
    header=True
).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductID</th><th>ProductName</th><th>Category</th><th>StockLevel</th><th>Price</th></tr></thead><tbody><tr><td>1</td><td>Product_1</td><td>Clothing</td><td>22</td><td>46.11</td></tr><tr><td>2</td><td>Product_2</td><td>Home & Kitchen</td><td>140</td><td>81.6</td></tr><tr><td>3</td><td>Product_3</td><td>Home & Kitchen</td><td>473</td><td>78.72</td></tr><tr><td>4</td><td>Product_4</td><td>Clothing</td><td>386</td><td>22.06</td></tr><tr><td>5</td><td>Product_5</td><td>Beauty & Health</td><td>284</td><td>17.97</td></tr></tbody></table></div>

# %%
#examine sales_transaction file
spark.read.csv(
    "/Volumes/retail_store/bronze/raw_data/sales_transaction.csv",
    header=True
).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransactionID</th><th>CustomerID</th><th>ProductID</th><th>QuantityPurchased</th><th>TransactionDate</th><th>Price</th></tr></thead><tbody><tr><td>1</td><td>103</td><td>120</td><td>3</td><td>01/01/23</td><td>30.43</td></tr><tr><td>2</td><td>436</td><td>126</td><td>1</td><td>01/01/23</td><td>15.19</td></tr><tr><td>3</td><td>861</td><td>55</td><td>3</td><td>01/01/23</td><td>67.76</td></tr><tr><td>4</td><td>271</td><td>27</td><td>2</td><td>01/01/23</td><td>65.77</td></tr><tr><td>5</td><td>107</td><td>118</td><td>1</td><td>01/01/23</td><td>14.55</td></tr></tbody></table></div>
